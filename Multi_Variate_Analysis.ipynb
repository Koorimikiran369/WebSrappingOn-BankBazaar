# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Clean_data_set.csv', index_col = 0)

# %%
df.tail(50)
# Out:
#                      Bank_Name       Bank_Type     Location  \
# 11925                   review  Saving Account      kolkata
# 11927                    Kotak  Saving Account      kolkata
# 11928     Punjab National Bank  Saving Account      kolkata
# 11929                   review  Saving Account      kolkata
# 11931                SBI Cards     Credit Card       indore
# 11932  Standard Chartered Bank     Credit Card       indore
# 11933               ICICI Bank     Credit Card       indore
# 11934                HSBC Bank     Credit Card       indore
# 11935                HDFC Bank     Credit Card       indore
# 11936                 Citibank     Credit Card       indore
# 11938                Axis Bank     Credit Card       indore
# 11939            IndusInd Bank     Credit Card       indore
# 11940            IndusInd Bank     Credit Card      kolkata
# 11941            IndusInd Bank     Credit Card    hyderabad
# 11942                   review     Credit Card       mumbai
# ...

# %%
df['Bank_Name'].value_counts()
# Out:
# HDFC Bank                                2196
# review                                   1566
# IndusInd Bank                            1459
# Citibank                                  643
# ICICI Bank                                521
# SBI Cards                                 489
# Axis Bank                                 400
# SBI                                       364
# Kotak                                     307
# Fullerton                                 267
# LIC                                       212
# YES Bank                                  203
# RBL Bank                                  175
# Incred                                    134
# HSBC Bank                                 133
# Canara Bank                                56
# Tata capital                               51
# Bajaj Finserv                              40
# Standard Chartered Bank                    37
# American Express                           37
# ...

# %% [markdown]
# ### IndusInd Bank

# %%
df[(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Bank_Type'].value_counts()
# Out:
# Credit Card       623
# Personal Loan      19
# Saving Account     15
# Car Loan            2
# Name: Bank_Type, dtype: int64

# %%
df[(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Bank_Type'].value_counts().plot.bar()
plt.title('IndusInd Bank 5.0 Rating Bank_Types')
plt.xlabel('Bank_Type')
# Out:
# Text(0.5, 0, 'Bank_Type')

# %% [markdown]
# #### Observayions:
#
# - In IdusInd Bank with 5.0 rating of Credit Card Bank_Types are very high
# - The count of Credit Card type is 623
# - Personal Loan types are 19 in same bank.

# %%
df[(df['Bank_Type']=='Credit Card')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts()
# Out:
#  hyderabad       130
#  bangalore       112
#  chennai          71
#  new              64
#  mumbai           52
#  kolkata          30
#  pune             28
#  ahmedabad        26
#  jaipur           19
#  thane            18
#  coimbatore       15
#  gurgaon           8
#  kochi             6
#  faridabad         6
#  secunderabad      5
#  noida             4
#  lucknow           4
#  indore            4
#  kanpur            4
#  ghaziabad         3
#  navi              3
#  greater           3
#  mohali            3
#  chandigarh        2
#  panchkula         2
#  ludhiana          1
# Name: Location, dtype: int64

# %%
df[(df['Bank_Type']=='Credit Card')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts().plot.bar()
plt.title('Credit Card Type of IndusInd Bank 5.0 Rating Locations')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# #### Observations:
#
# - IndusInd Bank the Credit Card type with 5.0 rating in hyderabad are more
# - the count is 130
# - bangalore location having second highest those type of banks and the count is 112

# %%
df[(df['Bank_Type']=='Personal Loan')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts()
# Out:
#  hyderabad    4
#  new          4
#  gurgaon      3
#  mumbai       3
#  chennai      2
#  erode        1
#  mysore       1
#  faridabad    1
# Name: Location, dtype: int64

# %%
df[(df['Bank_Type']=='Personal Loan')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts().plot.bar()

plt.title('Personal Loan Type of IndusInd Bank 5.0 Rating Locations')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# #### Observations:
#
# - in IndusInd Bank Personal Loan Type with 5.0 Rating is High in hyderabad
# - The count is 4
# - new bank is also 4

# %%
df[(df['Bank_Type']=='Saving Account')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts()
# Out:
#  hyderabad      5
#  bangalore      2
#  chennai        2
#  surat          1
#  gurgaon        1
#  tirunelveli    1
#  mysore         1
#  nellore        1
#  ranchi         1
# Name: Location, dtype: int64

# %%
df[(df['Bank_Type']=='Saving Account')&(df['Bank_Name']=='IndusInd Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts().plot.bar()
plt.title('Saving Account Type of IndusInd Bank 5.0 Rating Locations')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# #### Observations:
#
# - IndusInd Bank Saving Account Type with 5.0 rating is high in hyderabad
# - count is 5
# - bangalore having 2 IndusInd Banks with 5.0 rating of Saving Account Type

# %% [markdown]
# ### HDFC Bank

# %%
df[(df['Bank_Name']=='HDFC Bank')&(df['Bank_Rating']==5.0)]['Bank_Type'].value_counts()
# Out:
# Personal Loan     459
# Credit Card       319
# Saving Account    152
# Two Wheeler        18
# Car Loan           17
# Name: Bank_Type, dtype: int64

# %%
df[(df['Bank_Name']=='HDFC Bank')&(df['Bank_Rating']==5.0)]['Bank_Type'].value_counts().plot.bar()
plt.title('HDFC Bank 5.0 Rating Bank_Types')
plt.xlabel('Bank_Type')
# Out:
# Text(0.5, 0, 'Bank_Type')

# %%
d = df[(df['Bank_Type']=='Personal Loan')&(df['Bank_Name']=='HDFC Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts()

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Personal Loan Type of HDFC Bank 5.0 Rating Locations')
d.head(20).plot('barh',ax = ax[0])
d.tail(20).plot('bar',ax = ax[1])
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# ### Observations:
#
# - In the data set HDFC Bank Personal Loan Types are having 459 values rating with 5.0

# %%
d22 = df[(df['Bank_Name']=='HDFC Bank')&(df['Bank_Rating']==5.0)&(df['Bank_Type']=='Personal Loan')]

# %%
d22
# Out:
#        Bank_Name      Bank_Type        Location  \
# 4      HDFC Bank  Personal Loan     pudukkottai
# 5      HDFC Bank  Personal Loan     pudukkottai
# 9      HDFC Bank  Personal Loan          mysore
# 52     HDFC Bank  Personal Loan          jaipur
# 59     HDFC Bank  Personal Loan           surat
# 67     HDFC Bank  Personal Loan           surat
# 86     HDFC Bank  Personal Loan           dhule
# 93     HDFC Bank  Personal Loan          rajkot
# 133    HDFC Bank  Personal Loan        warangal
# 190    HDFC Bank  Personal Loan           ajmer
# 192    HDFC Bank  Personal Loan       jhunjhunu
# 193    HDFC Bank  Personal Loan       jhunjhunu
# 195    HDFC Bank  Personal Loan           alwar
# 203    HDFC Bank  Personal Loan      coimbatore
# 243    HDFC Bank  Personal Loan        hindupur
# 244    HDFC Bank  Personal Loan           kochi
# 310    HDFC Bank  Personal Loan      coimbatore
# 430    HDFC Bank  Personal Loan       bangalore
# ...

# %%
d22['Location'].value_counts()
# Out:
#  hyderabad         40
#  chennai           31
#  bangalore         30
#  new               14
#  coimbatore        13
#  ahmedabad         12
#  jaipur            12
#  mumbai            12
#  kolkata           10
#  vadodara           9
#  mysore             9
#  madurai            8
#  visakhapatnam      7
#  thane              7
#  tirupur            7
#  noida              6
#  pune               6
#  surat              6
#  tiruchirapalli     5
#  erode              5
#  warangal           5
#  vijayawada         5
#  nagpur             5
#  aurangabad         5
#  gurgaon            4
#  patna              4
#  kochi              4
#  jodhpur            4
#  indore             4
#  ludhiana           3
#                    ..
#  bhilwara           1
#  burdwan            1
#  bankura            1
#  virudhunagar       1
#  karur              1
#  sivakasi           1
#  dhule              1
#  akola              1
#  amritsar           1
#  panipat            1
# ...

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Personal Loan Type of HDFC Bank 5.0 Rating Locations')
d.head(10).plot('barh',ax = ax[0])
d.tail(10).plot('bar',ax = ax[1])
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %%
d11 = df[df['Bank_Name']=='review']['Location'].value_counts()

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
f.suptitle('review bank locations')
d11.head(20).plot('barh',ax = ax[0])
d11.tail(20).plot('bar',ax = ax[1])
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %%
d1 = df[(df['Bank_Type']=='Saving Account')&(df['Bank_Name']=='HDFC Bank')&(df['Bank_Rating']==5.0)]['Location'].value_counts()

# %%
d1
# Out:
#  bangalore             30
#  hyderabad             21
#  new                   13
#  chennai               12
#  mumbai                 7
#  pune                   5
#  coimbatore             4
#  kolkata                4
#  karnal                 3
#  thane                  3
#  jaipur                 3
#  vijayawada             2
#  secunderabad           2
#  ranchi                 2
#  navi                   2
#  gurgaon                2
#  tiruchirapalli         2
#  guntur                 2
#  namakkal               2
#  nellore                2
#  madurai                2
#  ahmedabad              2
#  faridabad              1
#  lucknow                1
#  jodhpur                1
#  bareilly               1
#  noida                  1
#  manjeri                1
#  kochi                  1
#  solapur                1
#  gorakhpur              1
#  nagda                  1
#  patiala                1
#  bhubaneshwar           1
#  anantapur              1
# ...

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Saving Account of HDFC Bank 5.0 Rating Locations')
d1.head(20).plot('barh',ax = ax[0])
d1.tail(20).plot('bar',ax = ax[1])
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# #### Observations:
#
# - Saving Account of HDFC Bank with 5.0 rating banglore location having more banks count is 30.
# - Saving Account of HDFC Bank with 5.0 rating chennai location having 2nd more banks count is 21.

# %%
d12 = df[(df['Bank_Type']=='Credit Card')&(df['Bank_Name']=='review')&(df['Bank_Rating']==5.0)]['Location'].value_counts()

# %%
d12.plot.bar()
plt.title('reviw bank of Credit card locations with 5.0 rating')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')
